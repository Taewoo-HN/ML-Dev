# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.preprocessing import RobustScaler, quantile_transform, StandardScaler, MinMaxScaler
from imblearn.over_sampling import ADASYN , SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier # XGBoost
from lightgbm import LGBMClassifier # LightGBM
warnings.filterwarnings('ignore')

# %%
santander_train = pd.read_csv('../data/santander-customer-satisfaction/train.csv')
santander_test = pd.read_csv('../data/santander-customer-satisfaction/test.csv')

# %%
santander_train=santander_train.drop('ID', axis=1, inplace=False)
test_df=santander_test.drop('ID', axis=1, inplace=False)

# %%
santander_train['var3'].value_counts()
santander_train['var3'].replace(-999999, 0, inplace=True)

# %%
test_df['var3'].replace(-999999, 0, inplace=True)

# %% [markdown]
# ---
# ## 스케일링 함수
#
# ---

# %%
def scale_data(data:pd.DataFrame, scaler:object)->pd.DataFrame:
    if scaler == 'Robust':
        scaler = RobustScaler()
        data_scaled = scaler.fit_transform(data)
    elif scaler == 'Quantile':
        data_scaled = quantile_transform(data, output_distribution='normal', random_state=150)
    elif scaler == 'Standard':
        scaler = StandardScaler()
        data_scaled = scaler.fit_transform(data)
    elif scaler == 'MinMax':
        scaler = MinMaxScaler()
        data_scaled = scaler.fit_transform(data)
    else:
        raise 'Invalid Scaler'
    return data_scaled

# %%
X_features = santander_train.drop('TARGET', axis=1, inplace=False)
y_target = santander_train['TARGET']

# %%
y_target.value_counts()
# Out:
# TARGET
# 0    73012
# 1     3008
# Name: count, dtype: int64

# %%
# 오버샘플링 함수
def sampling_data(data, target, sampler:object):
    if sampler == 'ada': 
        data , target = ADASYN(random_state=150).fit_resample(data, target)
    elif sampler == 'smote' : 
        data, target= SMOTE(random_state=150).fit_resample(data, target)
    else: raise 'Invalid Sampler'
    return data, target

# %%
X_data_sm, y_target_sm =  sampling_data(X_features, y_target, 'smote') # smote 오버샘플링
X_data_ada, y_target_ada =  sampling_data(X_features, y_target, 'ada') # ADASYN 오버샘플링

# %%
y_target_sm.value_counts()
# Out:
# TARGET
# 0    73012
# 1    73012
# Name: count, dtype: int64

# %%
X_features_std = scale_data(X_data_sm, 'Standard')
X_test_std = scale_data(test_df, 'Standard')

# %%
X_features_scaled = scale_data(X_data_sm ,'Quantile')
X_test_scaled = scale_data(test_df, 'Quantile')

# %%
X_train, X_val, y_train, y_val = train_test_split(X_features_scaled, y_target_sm, test_size=0.3, random_state=150)
X_train_std, X_val_std, y_train_std, y_val_std = train_test_split(X_features_std, y_target_sm, test_size=0.3, random_state=150)

# %%
# XGBoost, LightGBM
xgb_clf = XGBClassifier(n_estimators=500, random_state=150, max_depth=8, learning_rate=0.05, n_jobs=-1, eval_metric='auc')
lgbm_clf = LGBMClassifier(n_estimators=500, random_state=150, max_depth=8, learning_rate=0.05, n_jobs=-1, eval_metric='auc')

# %%
xgb_clf.fit(X_train, y_train, eval_set=[(X_val, y_val)])
lgbm_clf.fit(X_train, y_train, eval_set=[(X_val, y_val)])
# Out:
# [0]	validation_0-auc:0.93924
# [1]	validation_0-auc:0.93987
# [2]	validation_0-auc:0.94153
# [3]	validation_0-auc:0.94216
# [4]	validation_0-auc:0.94343
# [5]	validation_0-auc:0.94698
# [6]	validation_0-auc:0.94769
# [7]	validation_0-auc:0.94794
# [8]	validation_0-auc:0.94910
# [9]	validation_0-auc:0.94911
# [10]	validation_0-auc:0.94958
# [11]	validation_0-auc:0.95153
# [12]	validation_0-auc:0.95194
# [13]	validation_0-auc:0.95248
# [14]	validation_0-auc:0.95408
# [15]	validation_0-auc:0.95531
# [16]	validation_0-auc:0.95606
# [17]	validation_0-auc:0.95671
# [18]	validation_0-auc:0.95722
# [19]	validation_0-auc:0.95771
# [20]	validation_0-auc:0.95820
# [21]	validation_0-auc:0.95870
# [22]	validation_0-auc:0.95904
# [23]	validation_0-auc:0.95948
# [24]	validation_0-auc:0.95976
# [25]	validation_0-auc:0.96022
# [26]	validation_0-auc:0.96042
# [27]	validation_0-auc:0.96073
# [28]	validation_0-auc:0.96130
# [29]	validation_0-auc:0.96174
# [30]	validation_0-auc:0.96206
# [31]	validation_0-auc:0.96280
# [32]	validation_0-auc:0.96323
# [33]	validation_0-auc:0.96346
# [34]	validation_0-auc:0.96389
# [35]	validation_0-auc:0.96427
# [36]	validation_0-auc:0.96473
# [37]	validation_0-auc:0.96506
# [38]	validation_0-auc:0.96541
# [39]	validation_0-auc:0.96578
# [40]	validation_0-auc:0.96606
# [41]	validation_0-auc:0.96636
# [42]	validation_0-auc:0.96669
# [43]	validation_0-auc:0.96709
# [44]	validation_0-auc:0.96737
# [45]	validation_0-auc:0.96770
# [46]	validation_0-auc:0.96791
# [47]	validation_0-auc:0.96864
# [48]	validation_0-auc:0.96902
# [49]	validation_0-auc:0.96944
# [50]	validation_0-auc:0.96990
# [51]	validation_0-auc:0.97018
# [52]	validation_0-auc:0.97041
# [53]	validation_0-auc:0.97069
# [54]	validation_0-auc:0.97088
# [55]	validation_0-auc:0.97111
# [56]	validation_0-auc:0.97131
# [57]	validation_0-auc:0.97162
# [58]	validation_0-auc:0.97192
# [59]	validation_0-auc:0.97212
# [60]	validation_0-auc:0.97229
# [61]	validation_0-auc:0.97250
# [62]	validation_0-auc:0.97271
# [63]	validation_0-auc:0.97290
# [64]	validation_0-auc:0.97309
# [65]	validation_0-auc:0.97320
# [66]	validation_0-auc:0.97335
# [67]	validation_0-auc:0.97360
# [68]	validation_0-auc:0.97386
# [69]	validation_0-auc:0.97410
# [70]	validation_0-auc:0.97414
# [71]	validation_0-auc:0.97434
# [72]	validation_0-auc:0.97452
# [73]	validation_0-auc:0.97470
# [74]	validation_0-auc:0.97496
# [75]	validation_0-auc:0.97517
# [76]	validation_0-auc:0.97526
# [77]	validation_0-auc:0.97537
# [78]	validation_0-auc:0.97552
# [79]	validation_0-auc:0.97566
# [80]	validation_0-auc:0.97600
# [81]	validation_0-auc:0.97611
# [82]	validation_0-auc:0.97638
# [83]	validation_0-auc:0.97651
# [84]	validation_0-auc:0.97674
# [85]	validation_0-auc:0.97697
# [86]	validation_0-auc:0.97702
# [87]	validation_0-auc:0.97719
# [88]	validation_0-auc:0.97731
# [89]	validation_0-auc:0.97748
# [90]	validation_0-auc:0.97757
# [91]	validation_0-auc:0.97768
# [92]	validation_0-auc:0.97786
# [93]	validation_0-auc:0.97798
# [94]	validation_0-auc:0.97804
# [95]	validation_0-auc:0.97813
# [96]	validation_0-auc:0.97826
# [97]	validation_0-auc:0.97837
# [98]	validation_0-auc:0.97851
# [99]	validation_0-auc:0.97862
# [100]	validation_0-auc:0.97871
# [101]	validation_0-auc:0.97878
# [102]	validation_0-auc:0.97887
# [103]	validation_0-auc:0.97898
# [104]	validation_0-auc:0.97906
# [105]	validation_0-auc:0.97915
# [106]	validation_0-auc:0.97923
# [107]	validation_0-auc:0.97931
# [108]	validation_0-auc:0.97935
# [109]	validation_0-auc:0.97943
# [110]	validation_0-auc:0.97948
# [111]	validation_0-auc:0.97952
# [112]	validation_0-auc:0.97958
# [113]	validation_0-auc:0.97964
# [114]	validation_0-auc:0.97967
# [115]	validation_0-auc:0.97977
# [116]	validation_0-auc:0.97982
# [117]	validation_0-auc:0.97990
# [118]	validation_0-auc:0.97995
# [119]	validation_0-auc:0.97999
# [120]	validation_0-auc:0.98007
# [121]	validation_0-auc:0.98009
# [122]	validation_0-auc:0.98015
# [123]	validation_0-auc:0.98017
# [124]	validation_0-auc:0.98021
# [125]	validation_0-auc:0.98026
# [126]	validation_0-auc:0.98030
# [127]	validation_0-auc:0.98034
# [128]	validation_0-auc:0.98037
# [129]	validation_0-auc:0.98041
# [130]	validation_0-auc:0.98046
# [131]	validation_0-auc:0.98050
# [132]	validation_0-auc:0.98053
# [133]	validation_0-auc:0.98056
# [134]	validation_0-auc:0.98060
# [135]	validation_0-auc:0.98067
# [136]	validation_0-auc:0.98068
# [137]	validation_0-auc:0.98071
# [138]	validation_0-auc:0.98073
# [139]	validation_0-auc:0.98074
# [140]	validation_0-auc:0.98075
# [141]	validation_0-auc:0.98078
# [142]	validation_0-auc:0.98080
# [143]	validation_0-auc:0.98082
# [144]	validation_0-auc:0.98087
# [145]	validation_0-auc:0.98090
# [146]	validation_0-auc:0.98092
# [147]	validation_0-auc:0.98098
# [148]	validation_0-auc:0.98099
# [149]	validation_0-auc:0.98101
# [150]	validation_0-auc:0.98103
# [151]	validation_0-auc:0.98106
# [152]	validation_0-auc:0.98109
# [153]	validation_0-auc:0.98111
# [154]	validation_0-auc:0.98111
# [155]	validation_0-auc:0.98112
# [156]	validation_0-auc:0.98114
# [157]	validation_0-auc:0.98117
# [158]	validation_0-auc:0.98119
# [159]	validation_0-auc:0.98121
# [160]	validation_0-auc:0.98122
# [161]	validation_0-auc:0.98125
# [162]	validation_0-auc:0.98130
# [163]	validation_0-auc:0.98134
# [164]	validation_0-auc:0.98136
# [165]	validation_0-auc:0.98137
# [166]	validation_0-auc:0.98139
# [167]	validation_0-auc:0.98143
# [168]	validation_0-auc:0.98143
# [169]	validation_0-auc:0.98144
# [170]	validation_0-auc:0.98146
# [171]	validation_0-auc:0.98149
# [172]	validation_0-auc:0.98150
# [173]	validation_0-auc:0.98154
# [174]	validation_0-auc:0.98157
# [175]	validation_0-auc:0.98158
# [176]	validation_0-auc:0.98162
# [177]	validation_0-auc:0.98162
# [178]	validation_0-auc:0.98162
# [179]	validation_0-auc:0.98163
# [180]	validation_0-auc:0.98164
# [181]	validation_0-auc:0.98167
# [182]	validation_0-auc:0.98168
# [183]	validation_0-auc:0.98170
# [184]	validation_0-auc:0.98170
# [185]	validation_0-auc:0.98172
# [186]	validation_0-auc:0.98175
# [187]	validation_0-auc:0.98178
# [188]	validation_0-auc:0.98180
# [189]	validation_0-auc:0.98184
# [190]	validation_0-auc:0.98186
# [191]	validation_0-auc:0.98188
# [192]	validation_0-auc:0.98190
# [193]	validation_0-auc:0.98190
# [194]	validation_0-auc:0.98194
# [195]	validation_0-auc:0.98195
# [196]	validation_0-auc:0.98196
# [197]	validation_0-auc:0.98199
# [198]	validation_0-auc:0.98199
# [199]	validation_0-auc:0.98202
# [200]	validation_0-auc:0.98204
# [201]	validation_0-auc:0.98204
# [202]	validation_0-auc:0.98204
# [203]	validation_0-auc:0.98205
# [204]	validation_0-auc:0.98208
# [205]	validation_0-auc:0.98211
# [206]	validation_0-auc:0.98211
# [207]	validation_0-auc:0.98214
# [208]	validation_0-auc:0.98215
# [209]	validation_0-auc:0.98217
# [210]	validation_0-auc:0.98220
# [211]	validation_0-auc:0.98222
# [212]	validation_0-auc:0.98223
# [213]	validation_0-auc:0.98226
# [214]	validation_0-auc:0.98227
# [215]	validation_0-auc:0.98227
# [216]	validation_0-auc:0.98230
# [217]	validation_0-auc:0.98231
# [218]	validation_0-auc:0.98232
# [219]	validation_0-auc:0.98233
# [220]	validation_0-auc:0.98235
# [221]	validation_0-auc:0.98236
# [222]	validation_0-auc:0.98239
# [223]	validation_0-auc:0.98243
# [224]	validation_0-auc:0.98245
# [225]	validation_0-auc:0.98245
# [226]	validation_0-auc:0.98247
# [227]	validation_0-auc:0.98248
# [228]	validation_0-auc:0.98249
# [229]	validation_0-auc:0.98249
# [230]	validation_0-auc:0.98250
# [231]	validation_0-auc:0.98252
# [232]	validation_0-auc:0.98253
# [233]	validation_0-auc:0.98254
# [234]	validation_0-auc:0.98257
# [235]	validation_0-auc:0.98258
# [236]	validation_0-auc:0.98258
# [237]	validation_0-auc:0.98260
# [238]	validation_0-auc:0.98260
# [239]	validation_0-auc:0.98261
# [240]	validation_0-auc:0.98261
# [241]	validation_0-auc:0.98263
# [242]	validation_0-auc:0.98263
# [243]	validation_0-auc:0.98264
# [244]	validation_0-auc:0.98267
# [245]	validation_0-auc:0.98270
# [246]	validation_0-auc:0.98272
# [247]	validation_0-auc:0.98274
# [248]	validation_0-auc:0.98274
# [249]	validation_0-auc:0.98275
# [250]	validation_0-auc:0.98277
# [251]	validation_0-auc:0.98278
# [252]	validation_0-auc:0.98277
# [253]	validation_0-auc:0.98280
# [254]	validation_0-auc:0.98281
# [255]	validation_0-auc:0.98283
# [256]	validation_0-auc:0.98283
# [257]	validation_0-auc:0.98285
# [258]	validation_0-auc:0.98287
# [259]	validation_0-auc:0.98287
# [260]	validation_0-auc:0.98287
# [261]	validation_0-auc:0.98287
# [262]	validation_0-auc:0.98288
# [263]	validation_0-auc:0.98289
# [264]	validation_0-auc:0.98290
# [265]	validation_0-auc:0.98292
# [266]	validation_0-auc:0.98293
# [267]	validation_0-auc:0.98293
# [268]	validation_0-auc:0.98293
# [269]	validation_0-auc:0.98295
# [270]	validation_0-auc:0.98295
# [271]	validation_0-auc:0.98295
# [272]	validation_0-auc:0.98297
# [273]	validation_0-auc:0.98297
# [274]	validation_0-auc:0.98298
# [275]	validation_0-auc:0.98298
# [276]	validation_0-auc:0.98298
# [277]	validation_0-auc:0.98300
# [278]	validation_0-auc:0.98301
# [279]	validation_0-auc:0.98302
# [280]	validation_0-auc:0.98304
# [281]	validation_0-auc:0.98304
# [282]	validation_0-auc:0.98304
# [283]	validation_0-auc:0.98305
# [284]	validation_0-auc:0.98306
# [285]	validation_0-auc:0.98307
# [286]	validation_0-auc:0.98308
# [287]	validation_0-auc:0.98309
# [288]	validation_0-auc:0.98310
# [289]	validation_0-auc:0.98312
# [290]	validation_0-auc:0.98312
# [291]	validation_0-auc:0.98312
# [292]	validation_0-auc:0.98313
# [293]	validation_0-auc:0.98313
# [294]	validation_0-auc:0.98315
# [295]	validation_0-auc:0.98317
# [296]	validation_0-auc:0.98317
# [297]	validation_0-auc:0.98320
# [298]	validation_0-auc:0.98321
# [299]	validation_0-auc:0.98323
# [300]	validation_0-auc:0.98324
# [301]	validation_0-auc:0.98324
# [302]	validation_0-auc:0.98324
# [303]	validation_0-auc:0.98325
# [304]	validation_0-auc:0.98325
# [305]	validation_0-auc:0.98326
# [306]	validation_0-auc:0.98327
# [307]	validation_0-auc:0.98327
# [308]	validation_0-auc:0.98328
# [309]	validation_0-auc:0.98328
# [310]	validation_0-auc:0.98328
# [311]	validation_0-auc:0.98329
# [312]	validation_0-auc:0.98330
# [313]	validation_0-auc:0.98333
# [314]	validation_0-auc:0.98333
# [315]	validation_0-auc:0.98334
# [316]	validation_0-auc:0.98333
# [317]	validation_0-auc:0.98334
# [318]	validation_0-auc:0.98335
# [319]	validation_0-auc:0.98335
# [320]	validation_0-auc:0.98336
# [321]	validation_0-auc:0.98337
# [322]	validation_0-auc:0.98337
# [323]	validation_0-auc:0.98338
# [324]	validation_0-auc:0.98339
# [325]	validation_0-auc:0.98340
# [326]	validation_0-auc:0.98341
# [327]	validation_0-auc:0.98341
# [328]	validation_0-auc:0.98341
# [329]	validation_0-auc:0.98341
# [330]	validation_0-auc:0.98342
# [331]	validation_0-auc:0.98342
# [332]	validation_0-auc:0.98342
# [333]	validation_0-auc:0.98342
# [334]	validation_0-auc:0.98342
# [335]	validation_0-auc:0.98342
# [336]	validation_0-auc:0.98343
# [337]	validation_0-auc:0.98343
# [338]	validation_0-auc:0.98344
# [339]	validation_0-auc:0.98344
# [340]	validation_0-auc:0.98344
# [341]	validation_0-auc:0.98347
# [342]	validation_0-auc:0.98348
# [343]	validation_0-auc:0.98348
# [344]	validation_0-auc:0.98348
# [345]	validation_0-auc:0.98348
# [346]	validation_0-auc:0.98348
# [347]	validation_0-auc:0.98349
# [348]	validation_0-auc:0.98353
# [349]	validation_0-auc:0.98354
# [350]	validation_0-auc:0.98355
# [351]	validation_0-auc:0.98355
# [352]	validation_0-auc:0.98357
# [353]	validation_0-auc:0.98358
# [354]	validation_0-auc:0.98359
# [355]	validation_0-auc:0.98362
# [356]	validation_0-auc:0.98362
# [357]	validation_0-auc:0.98362
# [358]	validation_0-auc:0.98363
# [359]	validation_0-auc:0.98363
# [360]	validation_0-auc:0.98363
# [361]	validation_0-auc:0.98363
# [362]	validation_0-auc:0.98364
# [363]	validation_0-auc:0.98364
# [364]	validation_0-auc:0.98364
# [365]	validation_0-auc:0.98365
# [366]	validation_0-auc:0.98368
# [367]	validation_0-auc:0.98368
# [368]	validation_0-auc:0.98368
# [369]	validation_0-auc:0.98368
# [370]	validation_0-auc:0.98368
# [371]	validation_0-auc:0.98368
# [372]	validation_0-auc:0.98368
# [373]	validation_0-auc:0.98370
# [374]	validation_0-auc:0.98370
# [375]	validation_0-auc:0.98370
# [376]	validation_0-auc:0.98371
# [377]	validation_0-auc:0.98371
# [378]	validation_0-auc:0.98371
# [379]	validation_0-auc:0.98371
# [380]	validation_0-auc:0.98373
# [381]	validation_0-auc:0.98373
# [382]	validation_0-auc:0.98374
# [383]	validation_0-auc:0.98374
# [384]	validation_0-auc:0.98375
# [385]	validation_0-auc:0.98376
# [386]	validation_0-auc:0.98377
# [387]	validation_0-auc:0.98378
# [388]	validation_0-auc:0.98379
# [389]	validation_0-auc:0.98380
# [390]	validation_0-auc:0.98380
# [391]	validation_0-auc:0.98380
# [392]	validation_0-auc:0.98381
# [393]	validation_0-auc:0.98382
# [394]	validation_0-auc:0.98382
# [395]	validation_0-auc:0.98381
# [396]	validation_0-auc:0.98382
# [397]	validation_0-auc:0.98382
# [398]	validation_0-auc:0.98382
# [399]	validation_0-auc:0.98382
# [400]	validation_0-auc:0.98382
# [401]	validation_0-auc:0.98384
# [402]	validation_0-auc:0.98384
# [403]	validation_0-auc:0.98384
# [404]	validation_0-auc:0.98384
# [405]	validation_0-auc:0.98385
# [406]	validation_0-auc:0.98390
# [407]	validation_0-auc:0.98390
# [408]	validation_0-auc:0.98390
# [409]	validation_0-auc:0.98390
# [410]	validation_0-auc:0.98391
# [411]	validation_0-auc:0.98392
# [412]	validation_0-auc:0.98393
# [413]	validation_0-auc:0.98395
# [414]	validation_0-auc:0.98395
# [415]	validation_0-auc:0.98395
# [416]	validation_0-auc:0.98395
# [417]	validation_0-auc:0.98395
# [418]	validation_0-auc:0.98396
# [419]	validation_0-auc:0.98397
# [420]	validation_0-auc:0.98398
# [421]	validation_0-auc:0.98399
# [422]	validation_0-auc:0.98399
# [423]	validation_0-auc:0.98399
# [424]	validation_0-auc:0.98399
# [425]	validation_0-auc:0.98399
# [426]	validation_0-auc:0.98399
# [427]	validation_0-auc:0.98400
# [428]	validation_0-auc:0.98403
# [429]	validation_0-auc:0.98404
# [430]	validation_0-auc:0.98403
# [431]	validation_0-auc:0.98403
# [432]	validation_0-auc:0.98405
# [433]	validation_0-auc:0.98405
# [434]	validation_0-auc:0.98406
# [435]	validation_0-auc:0.98407
# [436]	validation_0-auc:0.98408
# [437]	validation_0-auc:0.98408
# [438]	validation_0-auc:0.98408
# [439]	validation_0-auc:0.98409
# [440]	validation_0-auc:0.98408
# [441]	validation_0-auc:0.98408
# [442]	validation_0-auc:0.98410
# [443]	validation_0-auc:0.98412
# [444]	validation_0-auc:0.98413
# [445]	validation_0-auc:0.98413
# [446]	validation_0-auc:0.98413
# [447]	validation_0-auc:0.98413
# [448]	validation_0-auc:0.98414
# [449]	validation_0-auc:0.98414
# [450]	validation_0-auc:0.98414
# [451]	validation_0-auc:0.98414
# [452]	validation_0-auc:0.98415
# [453]	validation_0-auc:0.98416
# [454]	validation_0-auc:0.98416
# [455]	validation_0-auc:0.98417
# [456]	validation_0-auc:0.98417
# [457]	validation_0-auc:0.98417
# [458]	validation_0-auc:0.98417
# [459]	validation_0-auc:0.98417
# [460]	validation_0-auc:0.98417
# [461]	validation_0-auc:0.98417
# [462]	validation_0-auc:0.98418
# [463]	validation_0-auc:0.98418
# [464]	validation_0-auc:0.98418
# [465]	validation_0-auc:0.98419
# [466]	validation_0-auc:0.98419
# [467]	validation_0-auc:0.98419
# [468]	validation_0-auc:0.98419
# [469]	validation_0-auc:0.98419
# [470]	validation_0-auc:0.98420
# [471]	validation_0-auc:0.98420
# [472]	validation_0-auc:0.98420
# [473]	validation_0-auc:0.98421
# [474]	validation_0-auc:0.98421
# [475]	validation_0-auc:0.98421
# [476]	validation_0-auc:0.98423
# [477]	validation_0-auc:0.98425
# [478]	validation_0-auc:0.98426
# [479]	validation_0-auc:0.98428
# [480]	validation_0-auc:0.98428
# [481]	validation_0-auc:0.98428
# [482]	validation_0-auc:0.98428
# [483]	validation_0-auc:0.98428
# [484]	validation_0-auc:0.98428
# [485]	validation_0-auc:0.98428
# [486]	validation_0-auc:0.98428
# [487]	validation_0-auc:0.98428
# [488]	validation_0-auc:0.98428
# [489]	validation_0-auc:0.98428
# [490]	validation_0-auc:0.98429
# [491]	validation_0-auc:0.98429
# [492]	validation_0-auc:0.98433
# [493]	validation_0-auc:0.98435
# [494]	validation_0-auc:0.98436
# [495]	validation_0-auc:0.98436
# [496]	validation_0-auc:0.98436
# [497]	validation_0-auc:0.98436
# [498]	validation_0-auc:0.98437
# [499]	validation_0-auc:0.98437
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Info] Number of positive: 50840, number of negative: 51376
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.025697 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 17963
# [LightGBM] [Info] Number of data points in the train set: 102216, number of used features: 258
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.497378 -> initscore=-0.010488
# [LightGBM] [Info] Start training from score -0.010488
# LGBMClassifier(eval_metric='auc', learning_rate=0.05, max_depth=8,
#                n_estimators=500, n_jobs=-1, random_state=150)

# %%
xgb_pred = xgb_clf.predict(X_test_scaled)
lgbm_pred = lgbm_clf.predict(X_test_scaled)
# Out:
# [LightGBM] [Warning] Unknown parameter: eval_metric

# %%
values_df = pd.DataFrame(data=[xgb_pred, lgbm_pred], index=['XGBoost', 'LightGBM']).T

# %%
values_df['LightGBM'].value_counts()
# Out:
# LightGBM
# 1    42295
# 0    33523
# Name: count, dtype: int64

# %%
values_df['XGBoost'].value_counts()
# Out:
# XGBoost
# 1    57103
# 0    18715
# Name: count, dtype: int64

# %%
from sklearn.metrics import confusion_matrix, roc_auc_score
confusion_matrix(values_df['XGBoost'], values_df['LightGBM'])
# Out:
# array([[16910,  1805],
#        [16613, 40490]])

# %%
roc_auc_score(values_df['XGBoost'], values_df['LightGBM'])
# Out:
# np.float64(0.8063114377608331)

# %%
meta_model = LogisticRegression()

# 스태킹 모델 정의
stacking_clf = StackingClassifier(
    estimators=[('xgb', xgb_clf), ('lgbm', lgbm_clf)],
    final_estimator=meta_model,
    cv=5
)

# 모델 학습
stacking_clf.fit(X_train, y_train)

# 예측 및 평가
y_pred = stacking_clf.predict(X_test_scaled)
y_pred_proba = stacking_clf.predict_proba(X_test_scaled)[:, 1]
# Out:
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Info] Number of positive: 50840, number of negative: 51376
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016869 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 17963
# [LightGBM] [Info] Number of data points in the train set: 102216, number of used features: 258
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.497378 -> initscore=-0.010488
# [LightGBM] [Info] Start training from score -0.010488
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Info] Number of positive: 40672, number of negative: 41100
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015038 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 17229
# [LightGBM] [Info] Number of data points in the train set: 81772, number of used features: 252
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.497383 -> initscore=-0.010468
# [LightGBM] [Info] Start training from score -0.010468
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Info] Number of positive: 40672, number of negative: 41101
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026448 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17265
# [LightGBM] [Info] Number of data points in the train set: 81773, number of used features: 251
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.497377 -> initscore=-0.010493
# [LightGBM] [Info] Start training from score -0.010493
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Info] Number of positive: 40672, number of negative: 41101
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014367 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 17222
# [LightGBM] [Info] Number of data points in the train set: 81773, number of used features: 252
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.497377 -> initscore=-0.010493
# [LightGBM] [Info] Start training from score -0.010493
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Info] Number of positive: 40672, number of negative: 41101
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017520 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 17192
# [LightGBM] [Info] Number of data points in the train set: 81773, number of used features: 248
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.497377 -> initscore=-0.010493
# [LightGBM] [Info] Start training from score -0.010493
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Info] Number of positive: 40672, number of negative: 41101
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020700 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 17241
# [LightGBM] [Info] Number of data points in the train set: 81773, number of used features: 252
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.497377 -> initscore=-0.010493
# [LightGBM] [Info] Start training from score -0.010493
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Warning] Unknown parameter: eval_metric
# [LightGBM] [Warning] Unknown parameter: eval_metric

# %%
print(y_pred)
print(y_pred_proba)
# Out:
# [1 1 1 ... 0 1 0]
# [0.98328453 0.97911097 0.89855174 ... 0.05786252 0.97909473 0.02672316]

# %%
roc_auc_score(y_pred, y_pred_proba)
# Out:
# np.float64(1.0)

# %%
Stacking_submission = pd.DataFrame(data={'ID':santander_test['ID'], 'TARGET':y_pred})

# %%
Stacking_submission.to_csv('./santander_submission/Stacking_submission_smote.csv', index=False)

# %%
xgb_submission = pd.DataFrame(data={'ID':santander_test['ID'], 'TARGET':xgb_pred})
lgbm_submission = pd.DataFrame(data={'ID':santander_test['ID'], 'TARGET':lgbm_pred})

# %%
xgb_submission.to_csv('./santander_submission/xgb_submission_smote_.csv', index=False)
lgbm_submission.to_csv('./santander_submission/lgbm_submission_smote_.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 xgb_submission.to_csv('./santander/xgb_submission_smote_0.csv', index=False)
#       2 lgbm_submission.to_csv('./santander/lgbm_submission_smote_0.csv', index=False)
#
# File C:\ProgramData\anaconda3\envs\ml-dev\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\envs\ml-dev\lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File C:\ProgramData\anaconda3\envs\ml-dev\lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File C:\ProgramData\anaconda3\envs\ml-dev\lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File C:\ProgramData\anaconda3\envs\ml-dev\lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File C:\ProgramData\anaconda3\envs\ml-dev\lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'santander'

# %% [markdown]
# ---
# ## 하이퍼 파라미터 튜닝
#
# ---

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import roc_auc_score

# %%
# 하이퍼 파라미터 튜닝
def hyperopt_train_test(params):
    xgb_test = XGBClassifier(**params)
    return cross_val_score(xgb_clf, X_features_std, y_target_sm, cv=5).mean()

# %%
param_space = {
    'n_estimators': hp.choice('n_estimators', range(100, 1000)),
    'max_depth': hp.choice('max_depth', range(1, 10)),
    'learning_rate': hp.quniform('learning_rate', 0.01, 0.5, 0.02),
    'colsample_bytree': hp.quniform('colsample_bytree', 0.1, 1, 0.01),
    'subsample': hp.quniform('subsample', 0.1, 1, 0.01),
    'gamma': hp.quniform('gamma', 0, 10, 1),
    'min_child_weight': hp.quniform('min_child_weight', 0, 10, 1),
    'eval_metric': hp.choice('eval_metric', ['auc'])
}

# %%
def f(params):
    acc = hyperopt_train_test(params)
    return {'loss': -acc, 'status': STATUS_OK}

# %%
trials = Trials()
best = fmin(f, param_space, algo=tpe.suggest, max_evals=20, trials=trials)
# Out:
# 100%|██████████| 20/20 [21:07<00:00, 63.39s/trial, best loss: -0.9348326910210005]

# %%
print(best)
# Out:
# {'colsample_bytree': np.float64(0.5), 'eval_metric': np.int64(0), 'gamma': np.float64(6.0), 'learning_rate': np.float64(0.16), 'max_depth': np.int64(8), 'min_child_weight': np.float64(8.0), 'n_estimators': np.int64(581), 'subsample': np.float64(0.8300000000000001)}

# %%
# 하이퍼 파라미터 튜닝 결과로 나온 최적의 파라미터
best_params = {
    "colsample_bytree": best['colsample_bytree'],
    'eval_metric': 'auc',
    'gamma': best['gamma'],
    'learning_rate': best['learning_rate'],
    'max_depth': best['max_depth'],
    'min_child_weight': best['min_child_weight'],
    'n_estimators': best['n_estimators'],
    'subsample': best['subsample']
}
xgb_hyperopt = XGBClassifier(**best_params)

# %%
xgb_hyperopt.fit(X_train, y_train, eval_set = [(X_val, y_val)])
# Out:
# [0]	validation_0-auc:0.92551
# [1]	validation_0-auc:0.94757
# [2]	validation_0-auc:0.95372
# [3]	validation_0-auc:0.95545
# [4]	validation_0-auc:0.95898
# [5]	validation_0-auc:0.96034
# [6]	validation_0-auc:0.96211
# [7]	validation_0-auc:0.96320
# [8]	validation_0-auc:0.96442
# [9]	validation_0-auc:0.96543
# [10]	validation_0-auc:0.96653
# [11]	validation_0-auc:0.96761
# [12]	validation_0-auc:0.96850
# [13]	validation_0-auc:0.96917
# [14]	validation_0-auc:0.96961
# [15]	validation_0-auc:0.97038
# [16]	validation_0-auc:0.97093
# [17]	validation_0-auc:0.97141
# [18]	validation_0-auc:0.97214
# [19]	validation_0-auc:0.97289
# [20]	validation_0-auc:0.97349
# [21]	validation_0-auc:0.97376
# [22]	validation_0-auc:0.97414
# [23]	validation_0-auc:0.97444
# [24]	validation_0-auc:0.97485
# [25]	validation_0-auc:0.97495
# [26]	validation_0-auc:0.97539
# [27]	validation_0-auc:0.97581
# [28]	validation_0-auc:0.97613
# [29]	validation_0-auc:0.97631
# [30]	validation_0-auc:0.97644
# [31]	validation_0-auc:0.97665
# [32]	validation_0-auc:0.97704
# [33]	validation_0-auc:0.97726
# [34]	validation_0-auc:0.97751
# [35]	validation_0-auc:0.97782
# [36]	validation_0-auc:0.97799
# [37]	validation_0-auc:0.97829
# [38]	validation_0-auc:0.97838
# [39]	validation_0-auc:0.97854
# [40]	validation_0-auc:0.97863
# [41]	validation_0-auc:0.97873
# [42]	validation_0-auc:0.97887
# [43]	validation_0-auc:0.97907
# [44]	validation_0-auc:0.97921
# [45]	validation_0-auc:0.97925
# [46]	validation_0-auc:0.97934
# [47]	validation_0-auc:0.97943
# [48]	validation_0-auc:0.97952
# [49]	validation_0-auc:0.97963
# [50]	validation_0-auc:0.97972
# [51]	validation_0-auc:0.97978
# [52]	validation_0-auc:0.97989
# [53]	validation_0-auc:0.97995
# [54]	validation_0-auc:0.97996
# [55]	validation_0-auc:0.97999
# [56]	validation_0-auc:0.98003
# [57]	validation_0-auc:0.98006
# [58]	validation_0-auc:0.98009
# [59]	validation_0-auc:0.98009
# [60]	validation_0-auc:0.98009
# [61]	validation_0-auc:0.98014
# [62]	validation_0-auc:0.98014
# [63]	validation_0-auc:0.98018
# [64]	validation_0-auc:0.98018
# [65]	validation_0-auc:0.98018
# [66]	validation_0-auc:0.98018
# [67]	validation_0-auc:0.98025
# [68]	validation_0-auc:0.98026
# [69]	validation_0-auc:0.98026
# [70]	validation_0-auc:0.98026
# [71]	validation_0-auc:0.98026
# [72]	validation_0-auc:0.98027
# [73]	validation_0-auc:0.98027
# [74]	validation_0-auc:0.98027
# [75]	validation_0-auc:0.98027
# [76]	validation_0-auc:0.98027
# [77]	validation_0-auc:0.98027
# [78]	validation_0-auc:0.98027
# [79]	validation_0-auc:0.98027
# [80]	validation_0-auc:0.98027
# [81]	validation_0-auc:0.98027
# [82]	validation_0-auc:0.98027
# [83]	validation_0-auc:0.98027
# [84]	validation_0-auc:0.98027
# [85]	validation_0-auc:0.98027
# [86]	validation_0-auc:0.98027
# [87]	validation_0-auc:0.98027
# [88]	validation_0-auc:0.98027
# [89]	validation_0-auc:0.98027
# [90]	validation_0-auc:0.98027
# [91]	validation_0-auc:0.98027
# [92]	validation_0-auc:0.98027
# [93]	validation_0-auc:0.98027
# [94]	validation_0-auc:0.98028
# [95]	validation_0-auc:0.98028
# [96]	validation_0-auc:0.98028
# [97]	validation_0-auc:0.98028
# [98]	validation_0-auc:0.98028
# [99]	validation_0-auc:0.98028
# [100]	validation_0-auc:0.98028
# [101]	validation_0-auc:0.98028
# [102]	validation_0-auc:0.98032
# [103]	validation_0-auc:0.98032
# [104]	validation_0-auc:0.98032
# [105]	validation_0-auc:0.98038
# [106]	validation_0-auc:0.98038
# [107]	validation_0-auc:0.98038
# [108]	validation_0-auc:0.98038
# [109]	validation_0-auc:0.98038
# [110]	validation_0-auc:0.98038
# [111]	validation_0-auc:0.98038
# [112]	validation_0-auc:0.98038
# [113]	validation_0-auc:0.98038
# [114]	validation_0-auc:0.98038
# [115]	validation_0-auc:0.98038
# [116]	validation_0-auc:0.98038
# [117]	validation_0-auc:0.98038
# [118]	validation_0-auc:0.98038
# [119]	validation_0-auc:0.98038
# [120]	validation_0-auc:0.98038
# [121]	validation_0-auc:0.98038
# [122]	validation_0-auc:0.98038
# [123]	validation_0-auc:0.98038
# [124]	validation_0-auc:0.98038
# [125]	validation_0-auc:0.98038
# [126]	validation_0-auc:0.98038
# [127]	validation_0-auc:0.98038
# [128]	validation_0-auc:0.98038
# [129]	validation_0-auc:0.98038
# [130]	validation_0-auc:0.98040
# [131]	validation_0-auc:0.98040
# [132]	validation_0-auc:0.98041
# [133]	validation_0-auc:0.98041
# [134]	validation_0-auc:0.98041
# [135]	validation_0-auc:0.98041
# [136]	validation_0-auc:0.98041
# [137]	validation_0-auc:0.98041
# [138]	validation_0-auc:0.98041
# [139]	validation_0-auc:0.98041
# [140]	validation_0-auc:0.98041
# [141]	validation_0-auc:0.98041
# [142]	validation_0-auc:0.98041
# [143]	validation_0-auc:0.98041
# [144]	validation_0-auc:0.98041
# [145]	validation_0-auc:0.98041
# [146]	validation_0-auc:0.98041
# [147]	validation_0-auc:0.98041
# [148]	validation_0-auc:0.98041
# [149]	validation_0-auc:0.98041
# [150]	validation_0-auc:0.98041
# [151]	validation_0-auc:0.98041
# [152]	validation_0-auc:0.98041
# [153]	validation_0-auc:0.98045
# [154]	validation_0-auc:0.98045
# [155]	validation_0-auc:0.98045
# [156]	validation_0-auc:0.98045
# [157]	validation_0-auc:0.98045
# [158]	validation_0-auc:0.98045
# [159]	validation_0-auc:0.98045
# [160]	validation_0-auc:0.98045
# [161]	validation_0-auc:0.98045
# [162]	validation_0-auc:0.98045
# [163]	validation_0-auc:0.98045
# [164]	validation_0-auc:0.98045
# [165]	validation_0-auc:0.98045
# [166]	validation_0-auc:0.98045
# [167]	validation_0-auc:0.98045
# [168]	validation_0-auc:0.98045
# [169]	validation_0-auc:0.98047
# [170]	validation_0-auc:0.98047
# [171]	validation_0-auc:0.98047
# [172]	validation_0-auc:0.98047
# [173]	validation_0-auc:0.98047
# [174]	validation_0-auc:0.98047
# [175]	validation_0-auc:0.98047
# [176]	validation_0-auc:0.98047
# [177]	validation_0-auc:0.98047
# [178]	validation_0-auc:0.98047
# [179]	validation_0-auc:0.98047
# [180]	validation_0-auc:0.98047
# [181]	validation_0-auc:0.98047
# [182]	validation_0-auc:0.98047
# [183]	validation_0-auc:0.98047
# [184]	validation_0-auc:0.98047
# [185]	validation_0-auc:0.98047
# [186]	validation_0-auc:0.98047
# [187]	validation_0-auc:0.98047
# [188]	validation_0-auc:0.98047
# [189]	validation_0-auc:0.98047
# [190]	validation_0-auc:0.98047
# [191]	validation_0-auc:0.98047
# [192]	validation_0-auc:0.98047
# [193]	validation_0-auc:0.98047
# [194]	validation_0-auc:0.98047
# [195]	validation_0-auc:0.98047
# [196]	validation_0-auc:0.98047
# [197]	validation_0-auc:0.98048
# [198]	validation_0-auc:0.98048
# [199]	validation_0-auc:0.98048
# [200]	validation_0-auc:0.98048
# [201]	validation_0-auc:0.98048
# [202]	validation_0-auc:0.98048
# [203]	validation_0-auc:0.98048
# [204]	validation_0-auc:0.98048
# [205]	validation_0-auc:0.98048
# [206]	validation_0-auc:0.98048
# [207]	validation_0-auc:0.98048
# [208]	validation_0-auc:0.98048
# [209]	validation_0-auc:0.98048
# [210]	validation_0-auc:0.98048
# [211]	validation_0-auc:0.98048
# [212]	validation_0-auc:0.98048
# [213]	validation_0-auc:0.98048
# [214]	validation_0-auc:0.98048
# [215]	validation_0-auc:0.98048
# [216]	validation_0-auc:0.98048
# [217]	validation_0-auc:0.98048
# [218]	validation_0-auc:0.98054
# [219]	validation_0-auc:0.98054
# [220]	validation_0-auc:0.98054
# [221]	validation_0-auc:0.98054
# [222]	validation_0-auc:0.98054
# [223]	validation_0-auc:0.98055
# [224]	validation_0-auc:0.98055
# [225]	validation_0-auc:0.98055
# [226]	validation_0-auc:0.98055
# [227]	validation_0-auc:0.98055
# [228]	validation_0-auc:0.98055
# [229]	validation_0-auc:0.98055
# [230]	validation_0-auc:0.98055
# [231]	validation_0-auc:0.98055
# [232]	validation_0-auc:0.98055
# [233]	validation_0-auc:0.98055
# [234]	validation_0-auc:0.98055
# [235]	validation_0-auc:0.98055
# [236]	validation_0-auc:0.98055
# [237]	validation_0-auc:0.98055
# [238]	validation_0-auc:0.98055
# [239]	validation_0-auc:0.98055
# [240]	validation_0-auc:0.98055
# [241]	validation_0-auc:0.98055
# [242]	validation_0-auc:0.98055
# [243]	validation_0-auc:0.98055
# [244]	validation_0-auc:0.98055
# [245]	validation_0-auc:0.98055
# [246]	validation_0-auc:0.98055
# [247]	validation_0-auc:0.98055
# [248]	validation_0-auc:0.98055
# [249]	validation_0-auc:0.98055
# [250]	validation_0-auc:0.98055
# [251]	validation_0-auc:0.98055
# [252]	validation_0-auc:0.98055
# [253]	validation_0-auc:0.98055
# [254]	validation_0-auc:0.98055
# [255]	validation_0-auc:0.98055
# [256]	validation_0-auc:0.98055
# [257]	validation_0-auc:0.98055
# [258]	validation_0-auc:0.98055
# [259]	validation_0-auc:0.98055
# [260]	validation_0-auc:0.98055
# [261]	validation_0-auc:0.98055
# [262]	validation_0-auc:0.98055
# [263]	validation_0-auc:0.98055
# [264]	validation_0-auc:0.98055
# [265]	validation_0-auc:0.98055
# [266]	validation_0-auc:0.98055
# [267]	validation_0-auc:0.98055
# [268]	validation_0-auc:0.98055
# [269]	validation_0-auc:0.98055
# [270]	validation_0-auc:0.98055
# [271]	validation_0-auc:0.98055
# [272]	validation_0-auc:0.98055
# [273]	validation_0-auc:0.98055
# [274]	validation_0-auc:0.98055
# [275]	validation_0-auc:0.98055
# [276]	validation_0-auc:0.98055
# [277]	validation_0-auc:0.98055
# [278]	validation_0-auc:0.98055
# [279]	validation_0-auc:0.98055
# [280]	validation_0-auc:0.98055
# [281]	validation_0-auc:0.98055
# [282]	validation_0-auc:0.98055
# [283]	validation_0-auc:0.98055
# [284]	validation_0-auc:0.98055
# [285]	validation_0-auc:0.98055
# [286]	validation_0-auc:0.98055
# [287]	validation_0-auc:0.98055
# [288]	validation_0-auc:0.98055
# [289]	validation_0-auc:0.98055
# [290]	validation_0-auc:0.98055
# [291]	validation_0-auc:0.98055
# [292]	validation_0-auc:0.98055
# [293]	validation_0-auc:0.98055
# [294]	validation_0-auc:0.98055
# [295]	validation_0-auc:0.98055
# [296]	validation_0-auc:0.98055
# [297]	validation_0-auc:0.98055
# [298]	validation_0-auc:0.98055
# [299]	validation_0-auc:0.98055
# [300]	validation_0-auc:0.98056
# [301]	validation_0-auc:0.98056
# [302]	validation_0-auc:0.98056
# [303]	validation_0-auc:0.98056
# [304]	validation_0-auc:0.98056
# [305]	validation_0-auc:0.98057
# [306]	validation_0-auc:0.98057
# [307]	validation_0-auc:0.98057
# [308]	validation_0-auc:0.98057
# [309]	validation_0-auc:0.98057
# [310]	validation_0-auc:0.98057
# [311]	validation_0-auc:0.98057
# [312]	validation_0-auc:0.98057
# [313]	validation_0-auc:0.98057
# [314]	validation_0-auc:0.98057
# [315]	validation_0-auc:0.98057
# [316]	validation_0-auc:0.98057
# [317]	validation_0-auc:0.98057
# [318]	validation_0-auc:0.98057
# [319]	validation_0-auc:0.98057
# [320]	validation_0-auc:0.98057
# [321]	validation_0-auc:0.98057
# [322]	validation_0-auc:0.98057
# [323]	validation_0-auc:0.98057
# [324]	validation_0-auc:0.98057
# [325]	validation_0-auc:0.98057
# [326]	validation_0-auc:0.98057
# [327]	validation_0-auc:0.98057
# [328]	validation_0-auc:0.98057
# [329]	validation_0-auc:0.98057
# [330]	validation_0-auc:0.98057
# [331]	validation_0-auc:0.98057
# [332]	validation_0-auc:0.98057
# [333]	validation_0-auc:0.98057
# [334]	validation_0-auc:0.98057
# [335]	validation_0-auc:0.98057
# [336]	validation_0-auc:0.98057
# [337]	validation_0-auc:0.98057
# [338]	validation_0-auc:0.98057
# [339]	validation_0-auc:0.98057
# [340]	validation_0-auc:0.98057
# [341]	validation_0-auc:0.98057
# [342]	validation_0-auc:0.98057
# [343]	validation_0-auc:0.98057
# [344]	validation_0-auc:0.98057
# [345]	validation_0-auc:0.98057
# [346]	validation_0-auc:0.98057
# [347]	validation_0-auc:0.98057
# [348]	validation_0-auc:0.98057
# [349]	validation_0-auc:0.98057
# [350]	validation_0-auc:0.98057
# [351]	validation_0-auc:0.98057
# [352]	validation_0-auc:0.98057
# [353]	validation_0-auc:0.98057
# [354]	validation_0-auc:0.98057
# [355]	validation_0-auc:0.98057
# [356]	validation_0-auc:0.98057
# [357]	validation_0-auc:0.98057
# [358]	validation_0-auc:0.98057
# [359]	validation_0-auc:0.98057
# [360]	validation_0-auc:0.98057
# [361]	validation_0-auc:0.98057
# [362]	validation_0-auc:0.98057
# [363]	validation_0-auc:0.98057
# [364]	validation_0-auc:0.98057
# [365]	validation_0-auc:0.98057
# [366]	validation_0-auc:0.98057
# [367]	validation_0-auc:0.98057
# [368]	validation_0-auc:0.98057
# [369]	validation_0-auc:0.98057
# [370]	validation_0-auc:0.98057
# [371]	validation_0-auc:0.98057
# [372]	validation_0-auc:0.98057
# [373]	validation_0-auc:0.98057
# [374]	validation_0-auc:0.98057
# [375]	validation_0-auc:0.98057
# [376]	validation_0-auc:0.98057
# [377]	validation_0-auc:0.98057
# [378]	validation_0-auc:0.98057
# [379]	validation_0-auc:0.98057
# [380]	validation_0-auc:0.98057
# [381]	validation_0-auc:0.98057
# [382]	validation_0-auc:0.98057
# [383]	validation_0-auc:0.98057
# [384]	validation_0-auc:0.98057
# [385]	validation_0-auc:0.98057
# [386]	validation_0-auc:0.98057
# [387]	validation_0-auc:0.98057
# [388]	validation_0-auc:0.98057
# [389]	validation_0-auc:0.98057
# [390]	validation_0-auc:0.98057
# [391]	validation_0-auc:0.98057
# [392]	validation_0-auc:0.98057
# [393]	validation_0-auc:0.98057
# [394]	validation_0-auc:0.98057
# [395]	validation_0-auc:0.98057
# [396]	validation_0-auc:0.98057
# [397]	validation_0-auc:0.98057
# [398]	validation_0-auc:0.98057
# [399]	validation_0-auc:0.98057
# [400]	validation_0-auc:0.98057
# [401]	validation_0-auc:0.98057
# [402]	validation_0-auc:0.98057
# [403]	validation_0-auc:0.98057
# [404]	validation_0-auc:0.98057
# [405]	validation_0-auc:0.98057
# [406]	validation_0-auc:0.98057
# [407]	validation_0-auc:0.98057
# [408]	validation_0-auc:0.98057
# [409]	validation_0-auc:0.98057
# [410]	validation_0-auc:0.98057
# [411]	validation_0-auc:0.98057
# [412]	validation_0-auc:0.98057
# [413]	validation_0-auc:0.98057
# [414]	validation_0-auc:0.98057
# [415]	validation_0-auc:0.98057
# [416]	validation_0-auc:0.98057
# [417]	validation_0-auc:0.98057
# [418]	validation_0-auc:0.98057
# [419]	validation_0-auc:0.98057
# [420]	validation_0-auc:0.98057
# [421]	validation_0-auc:0.98057
# [422]	validation_0-auc:0.98057
# [423]	validation_0-auc:0.98057
# [424]	validation_0-auc:0.98057
# [425]	validation_0-auc:0.98057
# [426]	validation_0-auc:0.98057
# [427]	validation_0-auc:0.98057
# [428]	validation_0-auc:0.98057
# [429]	validation_0-auc:0.98057
# [430]	validation_0-auc:0.98057
# [431]	validation_0-auc:0.98057
# [432]	validation_0-auc:0.98057
# [433]	validation_0-auc:0.98057
# [434]	validation_0-auc:0.98057
# [435]	validation_0-auc:0.98057
# [436]	validation_0-auc:0.98057
# [437]	validation_0-auc:0.98057
# [438]	validation_0-auc:0.98057
# [439]	validation_0-auc:0.98057
# [440]	validation_0-auc:0.98057
# [441]	validation_0-auc:0.98057
# [442]	validation_0-auc:0.98057
# [443]	validation_0-auc:0.98057
# [444]	validation_0-auc:0.98057
# [445]	validation_0-auc:0.98057
# [446]	validation_0-auc:0.98057
# [447]	validation_0-auc:0.98057
# [448]	validation_0-auc:0.98057
# [449]	validation_0-auc:0.98057
# [450]	validation_0-auc:0.98057
# [451]	validation_0-auc:0.98057
# [452]	validation_0-auc:0.98057
# [453]	validation_0-auc:0.98057
# [454]	validation_0-auc:0.98057
# [455]	validation_0-auc:0.98057
# [456]	validation_0-auc:0.98057
# [457]	validation_0-auc:0.98057
# [458]	validation_0-auc:0.98057
# [459]	validation_0-auc:0.98057
# [460]	validation_0-auc:0.98057
# [461]	validation_0-auc:0.98057
# [462]	validation_0-auc:0.98057
# [463]	validation_0-auc:0.98057
# [464]	validation_0-auc:0.98057
# [465]	validation_0-auc:0.98057
# [466]	validation_0-auc:0.98057
# [467]	validation_0-auc:0.98057
# [468]	validation_0-auc:0.98057
# [469]	validation_0-auc:0.98057
# [470]	validation_0-auc:0.98057
# [471]	validation_0-auc:0.98057
# [472]	validation_0-auc:0.98057
# [473]	validation_0-auc:0.98057
# [474]	validation_0-auc:0.98060
# [475]	validation_0-auc:0.98060
# [476]	validation_0-auc:0.98060
# [477]	validation_0-auc:0.98060
# [478]	validation_0-auc:0.98060
# [479]	validation_0-auc:0.98060
# [480]	validation_0-auc:0.98060
# [481]	validation_0-auc:0.98060
# [482]	validation_0-auc:0.98060
# [483]	validation_0-auc:0.98060
# [484]	validation_0-auc:0.98060
# [485]	validation_0-auc:0.98060
# [486]	validation_0-auc:0.98060
# [487]	validation_0-auc:0.98060
# [488]	validation_0-auc:0.98060
# [489]	validation_0-auc:0.98060
# [490]	validation_0-auc:0.98060
# [491]	validation_0-auc:0.98060
# [492]	validation_0-auc:0.98060
# [493]	validation_0-auc:0.98060
# [494]	validation_0-auc:0.98060
# [495]	validation_0-auc:0.98060
# [496]	validation_0-auc:0.98060
# [497]	validation_0-auc:0.98060
# [498]	validation_0-auc:0.98060
# [499]	validation_0-auc:0.98060
# [500]	validation_0-auc:0.98060
# [501]	validation_0-auc:0.98060
# [502]	validation_0-auc:0.98060
# [503]	validation_0-auc:0.98060
# [504]	validation_0-auc:0.98060
# [505]	validation_0-auc:0.98060
# [506]	validation_0-auc:0.98060
# [507]	validation_0-auc:0.98060
# [508]	validation_0-auc:0.98060
# [509]	validation_0-auc:0.98060
# [510]	validation_0-auc:0.98060
# [511]	validation_0-auc:0.98060
# [512]	validation_0-auc:0.98060
# [513]	validation_0-auc:0.98060
# [514]	validation_0-auc:0.98060
# [515]	validation_0-auc:0.98060
# [516]	validation_0-auc:0.98060
# [517]	validation_0-auc:0.98060
# [518]	validation_0-auc:0.98060
# [519]	validation_0-auc:0.98060
# [520]	validation_0-auc:0.98060
# [521]	validation_0-auc:0.98060
# [522]	validation_0-auc:0.98060
# [523]	validation_0-auc:0.98060
# [524]	validation_0-auc:0.98060
# [525]	validation_0-auc:0.98060
# [526]	validation_0-auc:0.98060
# [527]	validation_0-auc:0.98060
# [528]	validation_0-auc:0.98060
# [529]	validation_0-auc:0.98060
# [530]	validation_0-auc:0.98060
# [531]	validation_0-auc:0.98060
# [532]	validation_0-auc:0.98060
# [533]	validation_0-auc:0.98060
# [534]	validation_0-auc:0.98060
# [535]	validation_0-auc:0.98060
# [536]	validation_0-auc:0.98060
# [537]	validation_0-auc:0.98060
# [538]	validation_0-auc:0.98062
# [539]	validation_0-auc:0.98062
# [540]	validation_0-auc:0.98062
# [541]	validation_0-auc:0.98062
# [542]	validation_0-auc:0.98062
# [543]	validation_0-auc:0.98062
# [544]	validation_0-auc:0.98062
# [545]	validation_0-auc:0.98062
# [546]	validation_0-auc:0.98062
# [547]	validation_0-auc:0.98062
# [548]	validation_0-auc:0.98062
# [549]	validation_0-auc:0.98062
# [550]	validation_0-auc:0.98062
# [551]	validation_0-auc:0.98062
# [552]	validation_0-auc:0.98062
# [553]	validation_0-auc:0.98062
# [554]	validation_0-auc:0.98062
# [555]	validation_0-auc:0.98062
# [556]	validation_0-auc:0.98062
# [557]	validation_0-auc:0.98062
# [558]	validation_0-auc:0.98062
# [559]	validation_0-auc:0.98062
# [560]	validation_0-auc:0.98062
# [561]	validation_0-auc:0.98062
# [562]	validation_0-auc:0.98062
# [563]	validation_0-auc:0.98062
# [564]	validation_0-auc:0.98062
# [565]	validation_0-auc:0.98062
# [566]	validation_0-auc:0.98062
# [567]	validation_0-auc:0.98062
# [568]	validation_0-auc:0.98062
# [569]	validation_0-auc:0.98062
# [570]	validation_0-auc:0.98062
# [571]	validation_0-auc:0.98062
# [572]	validation_0-auc:0.98062
# [573]	validation_0-auc:0.98062
# [574]	validation_0-auc:0.98062
# [575]	validation_0-auc:0.98062
# [576]	validation_0-auc:0.98062
# [577]	validation_0-auc:0.98062
# [578]	validation_0-auc:0.98062
# [579]	validation_0-auc:0.98062
# [580]	validation_0-auc:0.98062
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=np.float64(0.5), device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='auc', feature_types=None, gamma=np.float64(6.0),
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=np.float64(0.16),
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=np.int64(8), max_leaves=None,
#               min_child_weight=np.float64(8.0), missing=nan,
#               monotone_constraints=None, multi_strategy=None,
#               n_estimators=np.int64(581), n_jobs=None, num_parallel_tree=None,
#               random_state=None, ...)

# %%
xgb_hyperopt_pred = xgb_hyperopt.predict(X_test_std)

# %%
y_pred_proba_opt = xgb_hyperopt.predict_proba(X_test_std)[:, 1]

# %%
xgb_hyperopt_submission = pd.DataFrame(data={'ID':santander_test['ID'], 'TARGET':xgb_hyperopt_pred})

# %%
confusion_matrix(xgb_hyperopt_pred, y_pred)
# Out:
# array([[    0,     0],
#        [18574, 57244]])

# %%
xgb_hyperopt_submission.to_csv('./santander_submission/xgb_hyperopt_submission.csv', index=False)
